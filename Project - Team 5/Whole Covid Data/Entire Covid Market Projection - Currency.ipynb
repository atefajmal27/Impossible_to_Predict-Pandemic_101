# %%
# Import libraries and dependencies
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import matplotlib

# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# '/Users/philipbonner/Desktop/Project - Team 5/Whole Covid Data'

# %%
gold=Path('gold-Current.csv')
silver_prices_df = Path('Silver Whole Portfolio')
platinum_prices_df = Path ('Platinum Portfolio Whole.xlsx')
bitcoin_prices_df = Path ('Bitcoin Whole Portfolio.xlsx')
ethereum_prices_df = Path('Ethereum Whole Portfolio.xlsx')

# %%
pd.read_csv(gold)
# Out:
#               Market Perth Mint Spot Perth Mint Spot.1 Perth Mint Spot.2  \
# 0     Metal/Currency            Gold              Gold              Gold
# 1          Priced In             USD               USD               AUD
# 2         Price Type             Bid               Ask               Bid
# 3            Summary            High              High              High
# 4           01/01/16             NaN               NaN               NaN
# ...              ...             ...               ...               ...
# 1673        27/07/20         1936.67            1944.6           2718.33
# 1674        28/07/20         1975.65           1983.72            2753.9
# 1675        29/07/20         1956.22            1964.2           2726.95
# 1676        30/07/20         1965.46           1973.61           2738.47
# 1677        31/07/20         1973.03           1981.05           2742.54
#
#      Perth Mint Spot.3 Perth Mint Spot.4 Perth Mint Spot.5 Perth Mint Spot.6  \
# ...

# %%
silver_prices = pd.read_excel(silver_prices_df, index_col='Date', infer_datetime_format = True, parse_dates = True)
silver_prices = silver_prices.sort_index()
silver_prices.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-9ab99240316c> in <module>
# ----> 1 silver_prices = pd.read_excel(silver_prices_df, index_col='Date', infer_datetime_format = True, parse_dates = True)
#       2 silver_prices = silver_prices.sort_index()
#       3 silver_prices.head()
#
# ~/opt/anaconda2/envs/py3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ...
